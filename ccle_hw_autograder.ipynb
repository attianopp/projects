# %%
from bs4 import BeautifulSoup
import requests
import re

#update with ccle link, must have tab of hw assignments
URL = 'https://ccle.ucla.edu/mod/assign/view.php?id=3180667&action=grading'
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')
homework_tab_html = soup.findAll(lambda tag: tag.has_attr('data-nodetype') and re.search(r'Homework Assignments', tag.text))
homework_link = "https://ccle.ucla.edu/course/view.php?id=86349&amp;show_all=1"
print(homework_link)
hw_page = requests.get(homework_link)
hw_soup = BeautifulSoup(hw_page.content, 'html.parser')
# Out:
# https://ccle.ucla.edu/course/view.php?id=86349&amp;show_all=1

# %%
print(hw_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-us" xml:lang="en-us">
#  <head>
#   <title>
#    Course: Introduction to Computer Organization
#   </title>
#   <link href="https://ccle.ucla.edu/theme/image.php/uclashared/theme/1597145766/favicon" rel="shortcut icon"/>
#   <meta content="app-id=1356392252, app-argument=https://ccle.ucla.edu/course/view.php?id=86349&amp;show_all=1" name="apple-itunes-app"/>
#   <link href="https://ccle.ucla.edu/admin/tool/mobile/mobile.webmanifest.php" rel="manifest"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,700,900" rel="stylesheet" type="text/css"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="moodle, Course: Introduction to Computer Organization" name="keywords"/>
#   <link href="https://ccle.ucla.edu/theme/yui_combo.php?rollup/3.17.2/yui-moodlesimple-min.css" rel="stylesheet" type="text/css">
#    <script id="firstthemesheet" type="text/css">
# ...

# %%
regex = re.search('[<\w\d\s-]*href="([\d\D\&\?]*)">[\w\d\s-]*',str(results[0]))
print(regex[0].split(">")[0].split("\"")[1])
# Out:
# https://ccle.ucla.edu/course/view.php?id=86349&amp;section=1

# %%
test = "https://shb.ais.ucla.edu/shibboleth-idp/profile/SAML2/Redirect/SSO?execution=e3s2"
values = {'username': 'attiano',
          'password': '1twopunch'}
r = requests.post(test, data=values)
print(r.content)
# Out:
# b'\t<!DOCTYPE html>\n<html class="no-js">\n\n<head>\n\t<meta charset="utf-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t<title>UCLA Single Sign-On</title>\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t<link rel="stylesheet" href="/shibboleth-idp/css/ucla-logon.1.0.5.css">\n\t<script src="/shibboleth-idp/js/modernizr.custom.1.0.5.js"></script>\n</head>\n\n<body>\n\n<header class="logo" role="banner"><img src="/shibboleth-idp/img/ucla-white.png" alt="UCLA"></header>\n\n<section class="content" role="main">\n\t<article role="status">\n\n\t\t<h1 class="error-title">The login request you submitted is invalid. Please try again.</h1> <p>To protect your account, the UCLA Single Sign-On Service prevents old or previously used login pages from use. You may have clicked browser\'s back button or waited too long at the Logon page before signing in. Further, this service uses cookies and javascript in your web browser.</p> <p>Please make sur
# ...
